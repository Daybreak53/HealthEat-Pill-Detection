# %%
# Git 저장소 클론
# !git clone -b dev https://github.com/Daybreak53/HealthEat-Pill-Detection.git
# %cd /content/HealthEat-Pill-Detection

# %%
# 라이브러리 설치
# !pip install -q ultralytics wandb scikit-learn pandas pyyaml iterative-stratification

# %%
# 데이터셋 다운로드
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !mkdir -p ./data
# !kaggle competitions download -c ai09-level1-project
# !unzip -q ai09-level1-project.zip -d ./data
# !rm ai09-level1-project.zip

# !kaggle datasets download -d daybreak53/healtheat-aihub-single-pills
# !unzip -q healtheat-aihub-single-pills.zip -d ./temp
# !mv ./temp/ai_hub_imgs/* ./data/sprint_ai_project1_data/train_images/
# !mv ./temp/ai_hub_jsons/* ./data/sprint_ai_project1_data/train_annotations/
# !rm -rf ./temp healtheat-aihub-single-pills.zip

# %%
# 전처리 및 data.yaml 생성
# !python src/preprocess_data.py

# %%
# 모델 학습
# !python src/train.py

# %%
# 학습된 best.pt 가중치로 검증 세트 평가
# !python src/validate.py

# %%
# 테스트 이미지 추론 및 Kaggle 제출 파일(CSV) 생성
# !python src/inference.py
